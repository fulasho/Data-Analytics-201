# %% [markdown]
# <a href="https://colab.research.google.com/github/fulasho/Data-Analytics-201/blob/main/Data_Analytics201_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Let load various libraries that we going to need for this analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Because the file obtained from NYC Open Data is a comma-separated value (CSV) file, the Pandas function pd.read_csv( ) is used to open and read the file.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head(25)
# Out:
#    School DBN  ... Percent Scoring CR
# 0      01M034  ...                 na
# 1      01M034  ...                 na
# 2      01M034  ...                 na
# 3      01M140  ...                 na
# 4      01M140  ...                 na
# 5      01M140  ...                 na
# 6      01M140  ...                 na
# 7      01M140  ...                 na
# 8      01M184  ...                 98
# 9      01M184  ...               78.4
# 10     01M184  ...                 98
# 11     01M184  ...                 na
# 12     01M188  ...                8.7
# 13     01M188  ...               68.2
# 14     01M188  ...                 50
# 15     01M188  ...                 na
# 16     01M188  ...                 na
# 17     01M188  ...                 na
# 18     01M292  ...                 na
# 19     01M292  ...                 na
# 20     01M292  ...                  0
# 21     01M292  ...                 30
# 22     01M292  ...               54.7
# 23     01M292  ...                  0
# ...

# %%
# Let check out the size of the dataframe(number of rows and columns)
df.shape
# Out:
# (212331, 15)

# %%
# Let display all columns names
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
# check out data type for different columns: object is equal to string data type 
df.dtypes
# Out:
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
# Let deal with duplicate rows and missing values
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 212326    False
# 212327    False
# 212328    False
# 212329    False
# 212330     True
# Length: 212331, dtype: bool

# %%
# Let see how many rows are duplicated
df.duplicated().sum()
# Out:
# 23819

# %%
# Let see the particular rows are
df[df.duplicated() == True]
# Out:
#        School DBN  ... Percent Scoring CR
# 3406       01M650  ...                 na
# 7571       08X507  ...                 na
# 9454       08X507  ...                 na
# 9484       08X507  ...                 na
# 11389      10X667  ...                 na
# ...           ...  ...                ...
# 212316     84X706  ...                 na
# 212317     84X706  ...                 na
# 212318     84X717  ...                 na
# 212319     84X717  ...                 na
# 212330     84X717  ...                 na
#
# [23819 rows x 15 columns]

# %%
# Making a list of missing value types
missing_values = ['s','na']
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')
na_values = missing_values

# %%
df.isna().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
# Do students in charter schools are better than those in public schools in common core Algebra?
# Let compare Franklin Roosevelt public school with others in NYC
